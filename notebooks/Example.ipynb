# %% [markdown]
# Skeleton Cells for Project

# %%
# Libraries
library(tidyverse)
library(repr)
library(infer)
library(cowplot)
library(broom)
library(GGally)
# Out:
# ── Attaching core tidyverse packages ──────────────────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.5
# ✔ forcats   1.0.0     ✔ stringr   1.5.1
# ✔ ggplot2   4.0.0     ✔ tibble    3.2.1
# ✔ lubridate 1.9.4     ✔ tidyr     1.3.1
# ✔ purrr     1.0.4
# ── Conflicts ────────────────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package to force all conflicts to become errors
# Warning message:
# package ‘ggplot2’ was built under R version 4.4.3
# Warning message:
# package ‘infer’ was built under R version 4.4.3
# Attaching package: ‘cowplot’
#
# The following object is masked from ‘package:lubridate’:
#
#     stamp
# Warning message:
# package ‘cowplot’ was built under R version 4.4.3
# Warning message:
# package ‘GGally’ was built under R version 4.4.3

# %%
# set your working directory properly to the folder containing the file
# you can use getwd() and setwd()
setwd("c:/Users/leoni/Documents/GitHub/stat-301-project")
sample_df<- read_csv("data/chicago_walkability_sample.csv")
columns_df <- read_tsv("data/COLUMN_DESCRIPTORS.tsv")

# pick your variables

columns <- c(
  # Categorical Variables
  "is_most_walkable",
  # Numerical variables
  "walkability_index",
  "pop_density_per_sqmi",
  "median_household_income",
  "median_home_value",
  "transit_service_frequency"
)

sample_df <- sample_df %>%
  select(all_of(columns)) %>%
  drop_na() # use if dropping
glimpse(sample_df)
# Out:
# Rows: 6000 Columns: 42
# ── Column specification ─────────────────────────────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (6): geoid, tract_name, metro, state, safe_walk_tier, walkability_tier
# dbl (32): walkability_index, walkability_pctile, county_ped_death_rate_per_100k, ped_safety_pctile, s...
# lgl  (4): is_most_walkable, is_affordable, is_walkable_affordable, is_commercial_desert
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 41 Columns: 2
# ── Column specification ─────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (2): geoid, 12-digit Census block group GEOID (state+county+tract+block group). Read as text; joi...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# ...

# %% [markdown]
# # EDA
#
# Do graphs of the distribution, correlation, and what not.
#
# Note what variables of categorical, what are not. Note why are we removing certain N/As instead of adding 0s. Note what variables are not normally distributed.
